# %% [markdown]
# Reference: [10 Minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/10min.html)
#
# This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](https://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '0.22.0'

# %% [markdown]
# # Object Creation
# See the [Data Structure Intro section](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)
#
# Three data structures in pandas:
# - Series
# - DataFrame
# - Panel (In 0.20.0, Panel is deprecated and will be removed in a future version)
#
# ## Series
# Creating a `Series` by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ## DataFrame
# Creating a `DataFrame` by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-03  0.159454  1.872819  1.125399  0.363066
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774
# 2013-01-06  0.797047  1.170157  0.446099 -0.554417

# %% [markdown]
# Creating a `DataFrame` by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing data
# See the [Basics section](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %%
# See the top & bottom rows of the frame
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-03  0.159454  1.872819  1.125399  0.363066
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774
# 2013-01-06  0.797047  1.170157  0.446099 -0.554417

# %%
# Display the index, columns, and the underlying numpy data
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.60092241, -0.3020055 , -1.45748707,  0.27365311],
#        [-0.12543946, -0.02037033,  2.40385235, -0.24861897],
#        [ 0.15945387,  1.87281873,  1.12539885,  0.3630658 ],
#        [-0.57125412, -0.72556215,  1.18356665, -0.24722075],
#        [-0.12570556,  1.60728692,  0.28132225, -0.53377362],
#        [ 0.79704689,  1.17015711,  0.44609939, -0.55441732]])

# %%
# Describe shows a quick statistic summary of your data
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.122504  0.600387  0.663792 -0.157885
# std    0.507866  1.087691  1.280980  0.393029
# min   -0.571254 -0.725562 -1.457487 -0.554417
# 25%   -0.125639 -0.231597  0.322517 -0.462485
# 50%    0.017007  0.574893  0.785749 -0.247920
# 75%    0.490555  1.498004  1.169025  0.143435
# max    0.797047  1.872819  2.403852  0.363066

# %%
# Transposing your data
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.600922   -0.125439    0.159454   -0.571254   -0.125706    0.797047
# B   -0.302005   -0.020370    1.872819   -0.725562    1.607287    1.170157
# C   -1.457487    2.403852    1.125399    1.183567    0.281322    0.446099
# D    0.273653   -0.248619    0.363066   -0.247221   -0.533774   -0.554417

# %%
# Sorting by an axis
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.273653 -1.457487 -0.302005  0.600922
# 2013-01-02 -0.248619  2.403852 -0.020370 -0.125439
# 2013-01-03  0.363066  1.125399  1.872819  0.159454
# 2013-01-04 -0.247221  1.183567 -0.725562 -0.571254
# 2013-01-05 -0.533774  0.281322  1.607287 -0.125706
# 2013-01-06 -0.554417  0.446099  1.170157  0.797047

# %%
# Sorting by values
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-06  0.797047  1.170157  0.446099 -0.554417
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774
# 2013-01-03  0.159454  1.872819  1.125399  0.363066

# %% [markdown]
# # Selection
# While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, `.at`, `.iat`, `.loc`, `.iloc` and `.ix`.
#
# See the indexing documentation [Indexing and Selecting Data](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)
#
# ## Getting
# Selecting a single column, which yields a `Series`, equivalent to `df.A`

# %%
df['A']
# Out:
# 2013-01-01    0.600922
# 2013-01-02   -0.125439
# 2013-01-03    0.159454
# 2013-01-04   -0.571254
# 2013-01-05   -0.125706
# 2013-01-06    0.797047
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via `[]`, which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-03  0.159454  1.872819  1.125399  0.363066

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-03  0.159454  1.872819  1.125399  0.363066
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221

# %% [markdown]
# ## Selection by label
# See more in [Selection by Label](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-label)
#
# For getting a cross section using a label

# %%
df.loc[dates[0]]
# Out:
# A    0.600922
# B   -0.302005
# C   -1.457487
# D    0.273653
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selecting on a multi-axis by label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.600922 -0.302005
# 2013-01-02 -0.125439 -0.020370
# 2013-01-03  0.159454  1.872819
# 2013-01-04 -0.571254 -0.725562
# 2013-01-05 -0.125706  1.607287
# 2013-01-06  0.797047  1.170157

# %% [markdown]
# Showing label slicing, both endpoints are *included*

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.125439 -0.020370
# 2013-01-03  0.159454  1.872819
# 2013-01-04 -0.571254 -0.725562

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -0.125439
# B   -0.020370
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# 0.6009224073297941

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.at[dates[0],'A']
# Out:
# 0.6009224073297941

# %% [markdown]
# ## Selection by position
# See more in [Selection by Position](https://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)
#
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# A   -0.571254
# B   -0.725562
# C    1.183567
# D   -0.247221
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04 -0.571254 -0.725562
# 2013-01-05 -0.125706  1.607287

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.125439  2.403852
# 2013-01-03  0.159454  1.125399
# 2013-01-05 -0.125706  0.281322

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619
# 2013-01-03  0.159454  1.872819  1.125399  0.363066

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.302005 -1.457487
# 2013-01-02 -0.020370  2.403852
# 2013-01-03  1.872819  1.125399
# 2013-01-04 -0.725562  1.183567
# 2013-01-05  1.607287  0.281322
# 2013-01-06  1.170157  0.446099

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# -0.020370327586675577

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# -0.020370327586675577

# %% [markdown]
# ## Boolean indexing
# Using a single column’s values to select data.

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653
# 2013-01-03  0.159454  1.872819  1.125399  0.363066
# 2013-01-06  0.797047  1.170157  0.446099 -0.554417

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met.

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.600922       NaN       NaN  0.273653
# 2013-01-02       NaN       NaN  2.403852       NaN
# 2013-01-03  0.159454  1.872819  1.125399  0.363066
# 2013-01-04       NaN       NaN  1.183567       NaN
# 2013-01-05       NaN  1.607287  0.281322       NaN
# 2013-01-06  0.797047  1.170157  0.446099       NaN

# %% [markdown]
# Using the `isin()` method for filtering:

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.600922 -0.302005 -1.457487  0.273653    one
# 2013-01-02 -0.125439 -0.020370  2.403852 -0.248619    one
# 2013-01-03  0.159454  1.872819  1.125399  0.363066    two
# 2013-01-04 -0.571254 -0.725562  1.183567 -0.247221  three
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774   four
# 2013-01-06  0.797047  1.170157  0.446099 -0.554417  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.159454  1.872819  1.125399  0.363066   two
# 2013-01-05 -0.125706  1.607287  0.281322 -0.533774  four

# %% [markdown]
# ## Setting
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0

# %% [markdown]
# Setting values by position

# %%
df.iat[0,1] = 0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.457487  5  NaN
# 2013-01-02 -0.125439 -0.020370  2.403852  5  1.0
# 2013-01-03  0.159454  1.872819  1.125399  5  2.0
# 2013-01-04 -0.571254 -0.725562  1.183567  5  3.0
# 2013-01-05 -0.125706  1.607287  0.281322  5  4.0
# 2013-01-06  0.797047  1.170157  0.446099  5  5.0

# %% [markdown]
# A `where` operation with setting.

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.457487 -5  NaN
# 2013-01-02 -0.125439 -0.020370 -2.403852 -5 -1.0
# 2013-01-03 -0.159454 -1.872819 -1.125399 -5 -2.0
# 2013-01-04 -0.571254 -0.725562 -1.183567 -5 -3.0
# 2013-01-05 -0.125706 -1.607287 -0.281322 -5 -4.0
# 2013-01-06 -0.797047 -1.170157 -0.446099 -5 -5.0

# %% [markdown]
# # Missing data
# pandas primarily uses the value `np.nan` to represent missing data. It is by default not included in computations. See the [Missing Data section](https://pandas.pydata.org/pandas-docs/stable/missing_data.html#missing-data)
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.457487  5  NaN  1.0
# 2013-01-02 -0.125439 -0.020370  2.403852  5  1.0  1.0
# 2013-01-03  0.159454  1.872819  1.125399  5  2.0  NaN
# 2013-01-04 -0.571254 -0.725562  1.183567  5  3.0  NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='any')
# Out:
#                    A        B         C  D    F    E
# 2013-01-02 -0.125439 -0.02037  2.403852  5  1.0  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.457487  5  5.0  1.0
# 2013-01-02 -0.125439 -0.020370  2.403852  5  1.0  1.0
# 2013-01-03  0.159454  1.872819  1.125399  5  2.0  5.0
# 2013-01-04 -0.571254 -0.725562  1.183567  5  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are `nan`

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# # Operations
# See the [Basic section on Binary Ops](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)
#
# ## Stats
# Operations in general *exclude* missing data.
#
# Performing a descriptive statistic

# %%
df.mean()
# Out:
# A    0.022350
# B    0.650722
# C    0.663792
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    0.885628
# 2013-01-02    1.651609
# 2013-01-03    2.031534
# 2013-01-04    1.577350
# 2013-01-05    2.152581
# 2013-01-06    2.482661
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.840546  0.872819  0.125399  4.0  1.0
# 2013-01-04 -3.571254 -3.725562 -1.816433  2.0  0.0
# 2013-01-05 -5.125706 -3.392713 -4.718678  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ## Apply
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -1.457487   5   NaN
# 2013-01-02 -0.125439 -0.020370  0.946365  10   1.0
# 2013-01-03  0.034014  1.852448  2.071764  15   3.0
# 2013-01-04 -0.537240  1.126886  3.255331  20   6.0
# 2013-01-05 -0.662945  2.734173  3.536653  25  10.0
# 2013-01-06  0.134102  3.904330  3.982752  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.368301
# B    2.598381
# C    3.861339
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## Histogramming
# See more at [Histogramming and Discretization](https://pandas.pydata.org/pandas-docs/stable/basics.html#basics-discretization)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    2
# 1    5
# 2    4
# 3    5
# 4    0
# 5    1
# 6    2
# 7    2
# 8    5
# 9    5
# dtype: int32

# %%
s.value_counts()
# Out:
# 5    4
# 2    3
# 4    1
# 1    1
# 0    1
# dtype: int64

# %% [markdown]
# ## String methods
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions](https://docs.python.org/2/library/re.html) by default (and in some cases always uses them). See more at [Vectorized String Methods](https://pandas.pydata.org/pandas-docs/stable/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# # Merge
# ## Concat
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging)
#
# Concatenating pandas objects together with `concat()`:

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.867582  0.739003 -1.478943 -0.078346
# 1  1.746408  1.825240 -0.961043  1.271230
# 2 -0.742994  0.353766 -0.245665 -0.724160
# 3 -0.653510 -0.444505  0.786285 -0.445364
# 4 -0.520892  2.007290  1.338185  0.184830
# 5  0.516447  1.295601 -0.457689  0.205638
# 6  0.188975  1.659647  1.285009  1.650270
# 7  0.285176 -0.058342  0.618015  0.837740
# 8  0.389411 -1.097877  0.165664 -0.415836
# 9 -1.218568  1.892794  0.503727  1.676071

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.867582  0.739003 -1.478943 -0.078346
# 1  1.746408  1.825240 -0.961043  1.271230
# 2 -0.742994  0.353766 -0.245665 -0.724160
# 3 -0.653510 -0.444505  0.786285 -0.445364
# 4 -0.520892  2.007290  1.338185  0.184830
# 5  0.516447  1.295601 -0.457689  0.205638
# 6  0.188975  1.659647  1.285009  1.650270
# 7  0.285176 -0.058342  0.618015  0.837740
# 8  0.389411 -1.097877  0.165664 -0.415836
# 9 -1.218568  1.892794  0.503727  1.676071

# %% [markdown]
# ## Join
# SQL style merges. See the [Database style joining](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
print(left)
print(right)
pd.merge(left, right, on='key')
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2
#    key  rval
# 0  foo     4
# 1  foo     5
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# Another example that can be given is:

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
print(left)
print(right)
pd.merge(left, right, on='key')
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2
#    key  rval
# 0  foo     4
# 1  bar     5
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Append
# Append rows to a dataframe. See the [Appending](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging-concatenation)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.168691 -0.429969 -1.016681  0.576525
# 1  0.425951 -0.008628 -1.585122 -0.775582
# 2 -0.246147  0.213400 -0.328071 -2.225331
# 3 -1.143805  1.141960 -0.718819  1.673068
# 4 -0.356394 -0.812613 -0.686041 -0.818286
# 5  0.104510  0.497244 -0.261960 -1.394767
# 6 -1.196362 -0.311424 -0.370388  1.985359
# 7  1.964252 -0.932028  0.684162  0.733757

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.168691 -0.429969 -1.016681  0.576525
# 1  0.425951 -0.008628 -1.585122 -0.775582
# 2 -0.246147  0.213400 -0.328071 -2.225331
# 3 -1.143805  1.141960 -0.718819  1.673068
# 4 -0.356394 -0.812613 -0.686041 -0.818286
# 5  0.104510  0.497244 -0.261960 -1.394767
# 6 -1.196362 -0.311424 -0.370388  1.985359
# 7  1.964252 -0.932028  0.684162  0.733757
# 8 -1.143805  1.141960 -0.718819  1.673068

# %% [markdown]
# # Grouping
# By “group by” we are referring to a process involving one or more of the following steps
# - **Splitting** the data into groups based on some criteria
# - **Applying** a function to each group independently
# - **Combining** the results into a data structure
#
# See the [Grouping section](https://pandas.pydata.org/pandas-docs/stable/groupby.html#groupby)

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

df
# Out:
#      A      B         C         D
# 0  foo    one  1.335140  0.665936
# 1  bar    one  1.388261 -0.039989
# 2  foo    two -0.129813  0.459066
# 3  bar  three -0.249745 -0.881869
# 4  foo    two -0.432406  0.106957
# 5  bar    two -1.404341  0.524169
# 6  foo    one  2.292622 -1.100059
# 7  foo  three -1.128241  0.204058

# %% [markdown]
# Grouping and then applying a function `sum` to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.265825 -0.397690
# foo  1.937301  0.335958

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, which we then apply the function.

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.388261 -0.039989
#     three -0.249745 -0.881869
#     two   -1.404341  0.524169
# foo one    3.627761 -0.434123
#     three -1.128241  0.204058
#     two   -0.562220  0.566023

# %% [markdown]
# # Reshaping
# See the sections on [Hierarchical Indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) and [Reshaping](https://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking).
#
# ## Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.391639 -0.439129
#       two     1.802635 -0.506052
# baz   one    -1.345048 -0.959209
#       two    -1.747120  0.583459

# %% [markdown]
# The `stack()` method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.391639
#                B   -0.439129
#        two     A    1.802635
#                B   -0.506052
# baz    one     A   -1.345048
#                B   -0.959209
#        two     A   -1.747120
#                B    0.583459
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a `MultiIndex` as the `index`), the inverse operation of `stack()` is `unstack()`, which by default unstacks the **last level**:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.391639 -0.439129
#       two     1.802635 -0.506052
# baz   one    -1.345048 -0.959209
#       two    -1.747120  0.583459

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.391639  1.802635
#       B -0.439129 -0.506052
# baz   A -1.345048 -1.747120
#       B -0.959209  0.583459

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.391639 -1.345048
#        B -0.439129 -0.959209
# two    A  1.802635 -1.747120
#        B -0.506052  0.583459

# %% [markdown]
# ## Pivot Tables
# See the section on [Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot).

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.959572  1.342505
# 1     one  B  foo  2.208672  1.902595
# 2     two  C  foo -1.507068  0.346709
# 3   three  A  bar  1.051984 -0.989130
# 4     one  B  bar -0.794927 -0.763567
# 5     one  C  bar  0.095934  0.188399
# 6     two  A  foo  0.182157 -0.175133
# 7   three  B  foo  0.589816 -0.420993
# 8     one  C  foo -0.570596  1.374792
# 9     one  A  bar -2.589956 -0.751808
# 10    two  B  bar  0.396896 -0.514118
# 11  three  C  bar  1.635787 -0.660013

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -2.589956 -0.959572
#       B -0.794927  2.208672
#       C  0.095934 -0.570596
# three A  1.051984       NaN
#       B       NaN  0.589816
#       C  1.635787       NaN
# two   A       NaN  0.182157
#       B  0.396896       NaN
#       C       NaN -1.507068

# %% [markdown]
# # Time series
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries)

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    24838
# Freq: 5T, dtype: int32

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    1.282382
# 2012-03-07    0.251423
# 2012-03-08   -0.391015
# 2012-03-09   -0.515966
# 2012-03-10   -0.445729
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.282382
# 2012-03-07 00:00:00+00:00    0.251423
# 2012-03-08 00:00:00+00:00   -0.391015
# 2012-03-09 00:00:00+00:00   -0.515966
# 2012-03-10 00:00:00+00:00   -0.445729
# Freq: D, dtype: float64

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    1.282382
# 2012-03-06 19:00:00-05:00    0.251423
# 2012-03-07 19:00:00-05:00   -0.391015
# 2012-03-08 19:00:00-05:00   -0.515966
# 2012-03-09 19:00:00-05:00   -0.445729
# Freq: D, dtype: float64

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    0.097102
# 2012-02-29   -0.611359
# 2012-03-31    0.678012
# 2012-04-30    1.151806
# 2012-05-31   -1.671074
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.097102
# 2012-02   -0.611359
# 2012-03    0.678012
# 2012-04    1.151806
# 2012-05   -1.671074
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.097102
# 2012-02-01   -0.611359
# 2012-03-01    0.678012
# 2012-04-01    1.151806
# 2012-05-01   -1.671074
# Freq: MS, dtype: float64

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    1.625012
# 1990-06-01 09:00    1.453981
# 1990-09-01 09:00    0.446995
# 1990-12-01 09:00    0.377095
# 1991-03-01 09:00    0.344640
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
# pandas can include categorical data in a DataFrame. For full docs, see the [categorical introduction](https://pandas.pydata.org/pandas-docs/stable/categorical.html#categorical) and the [API documentation](https://pandas.pydata.org/pandas-docs/stable/api.html#api-categorical).

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %% [markdown]
# Convert the raw grades to a categorical data type.

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %% [markdown]
# Rename the categories to more meaningful names (assigning to `Series.cat.categories` is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under `Series .cat` return a new `Series` per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %% [markdown]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
